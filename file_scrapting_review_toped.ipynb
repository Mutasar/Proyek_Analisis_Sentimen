# %% [markdown]
# <a href="https://colab.research.google.com/github/Mutasar/Proyek_Analisis_Sentimen/blob/main/file_scrapting_review_toped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd
import tempfile
import nest_asyncio
import undetected_chromedriver as uc
from playwright.sync_api import sync_playwright

# %%
    # 1. Baca file CSV yang berisi data input (misalnya, daftar URL)
    try:
        # Gunakan export link dari Google Drive
        csv_url = 'https://drive.google.com/uc?export=download&id=1GLyhzyN3XNgmC3ftv4Klmvtlt_Dc7XzD'
        df = pd.read_csv(csv_url) # Gunakan export link di sini
        urls_to_scrape = df_input['content'].tolist() # Ganti 'URL_Column' dengan nama kolom yang berisi URL di CSV Anda
    except FileNotFoundError: # Meskipun ini tidak akan terjadi dengan URL, tetap baik untuk error handling
        print("Error: File CSV tidak dapat diakses dari URL.")
        urls_to_scrape = [] # Atur daftar kosong jika file tidak ditemukan
    except Exception as e:
        print(f"Terjadi kesalahan saat membaca file CSV dari Google Drive: {e}")
        urls_to_scrape = [] # Atur daftar kosong jika terjadi error

    # Sisa kode Anda untuk menyiapkan Selenium Driver dan scraping
    # ... (kode untuk driver setup dan scraping seperti sebelumnya)

# %%
nama_file_output = 'hasil_scraping.csv' # Beri nama file output Anda

# Simpan DataFrame ke CSV
df.to_csv(nama_file_output, index=False)

print(f"Data hasil scraping berhasil disimpan ke file '{nama_file_output}'")

# Opsional: Tampilkan beberapa baris pertama untuk verifikasi
print("\nPreview data yang disimpan:")
print(df.head())
# Out:
# Data hasil scraping berhasil disimpan ke file 'hasil_scraping.csv'
#
# Preview data yang disimpan:
#           userName  score                   at  \
# 0  Pengguna Google      5  2024-09-08 03:31:50
# 1  Pengguna Google      1  2024-09-08 03:29:56
# 2  Pengguna Google      5  2024-09-08 03:26:38
# 3  Pengguna Google      5  2024-09-08 03:25:14
# 4  Pengguna Google      1  2024-09-08 03:24:01
#
#                                              content
# 0                                      makasih toped
# 1  Aplikasi php sudah banyak dikasih promo &sudah...
# 2                                        mantab... 👍
# 3                                          Good good
# 4  Sangat buruk sebagai pengguna lama akun affali...

# %%
from google.colab import files

# Ganti 'nama_file_anda.csv' dengan nama file CSV yang ingin Anda unduh
files.download('hasil_scraping.csv')
